# %% [markdown]
# # Compare load APIs

# %% [markdown]
# ## Spark

# %%
#generic
def load(self, path=None, format=None, schema=None, **options):
    pass

# specific
def csv(self, path, schema=None, sep=None, encoding=None, quote=None, escape=None,
            comment=None, header=None, inferSchema=None, ignoreLeadingWhiteSpace=None,
            ignoreTrailingWhiteSpace=None, nullValue=None, nanValue=None, positiveInf=None,
            negativeInf=None, dateFormat=None, timestampFormat=None, maxColumns=None,
            maxCharsPerColumn=None, maxMalformedLogPerPartition=None, mode=None,
            columnNameOfCorruptRecord=None, multiLine=None, charToEscapeQuoteEscaping=None,
            samplingRatio=None, enforceSchema=None, emptyValue=None):
    pass

# %% [markdown]
# ```
# spark = pyspark.Create()
# spark.read.load('http://file', format='csv')
# spark.read.csv('http://file')
# ```

# %% [markdown]
# ## Optimus

# %%
#no generic

def csv(path, sep=',', header='true', infer_schema='true', *args, **kwargs):
    pass

# %% [markdown]
# ```
# op = Optimus()
# op.load.csv('http://file')
# ```

# %% [markdown]
# ## Dask/Pandas

# %%
def read_csv(urlpath, blocksize=64000000, collection=True, lineterminator=None, 
             sample=256000, enforce=False, assume_missing=False, float_precision=None,
             storage_options=None, include_path_column=False, sep=', ', delimiter=None, 
             header='infer', names=None, index_col=None, usecols=None, squeeze=False, 
             prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, 
             true_values=None, false_values=None, skipinitialspace=False, skiprows=None, 
             skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, 
             verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, 
             keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, 
             compression='infer', thousands=None, decimal=b'.', quotechar='"', memory_map=False,
             quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, 
             tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, 
             low_memory=True):
    pass

# %% [markdown]
# ```
# import dask.dataframe as dd
# import pandas as pd
#
# dd.read_csv('http://file')
# pd.read_csv('http://file')
# ```

# %% [markdown]
# ## Koalas

# %%
def read_csv(path, header='infer', names=None, usecols=None, 
             mangle_dupe_cols=True, parse_dates=False, comment=None):
    pass

# %% [markdown]
# ```
# import databricks.koalas as ks
#
# ks.read_csv('http://file')
# ```

# %% [markdown]
# ## Datafaucet

# %%
# generic (uniform, but opaque)
def read(path, provider=None, **kwargs):
    pass

# specific (options are listed directly)
def read_csv(path, provider=None, sep=None, encoding=None, quote=None, escape=None,
            comment=None, header=None, inferSchema=None, ignoreLeadingWhiteSpace=None,
            ignoreTrailingWhiteSpace=None, nullValue=None, nanValue=None, positiveInf=None,
            negativeInf=None, dateFormat=None, timestampFormat=None, maxColumns=None,
            maxCharsPerColumn=None, maxMalformedLogPerPartition=None, mode=None,
            columnNameOfCorruptRecord=None, multiLine=None, charToEscapeQuoteEscaping=None,
            samplingRatio=None, enforceSchema=None, emptyValue=None):
    pass

# %%
a = None
isinstance(a, type(None))
# Out:
# True

# %% [markdown]
# ```
# path:
#     a metadata alias
#     a jdbc uri (jdbc:<subprotocol>:<subname>)
#     a url ( hdfs://)
#     a local file
#     a table name (provider is a jdbc service)
#     a sql query (provider is a jdbc service)
#     a resource
#
# provider:
#     a metadata alias
#     a jdbc uri (jdbc:<subprotocol>:<subname>)
#     a url ( hdfs://)
#     a local directory
#     a data service (like elastic HTTP REST api)
#     a resource ( defined with resource( ...) )
#
# a resource is an object (currently a dict),
# it can be defined inline in the code or in the metadata yaml file
#
# resource(path_or_url, alias, host, service, port, user, password, driver, database, schema, table, format, hostname, username, **kwargs)
#
# merging resources:
# a resource with no schema/service/format is 'abstract'
# if service is defined the resource is 'concrete'
#
# resource:
#     <alias_name>:
#         path,
#         format
#
#         host | hostname
#         port
#
#         driver,
#         database,
#         schema,
#         table,
#         user | username ,
#         password,
#
#         parent'
#
# service: mysql
#         format: jdbc
#         path: sakila
#         hostname: mysql
#         username: sakila
#         password: "{{ env('MYSQL_USER_PASSWORD') }}"
#         database:
#         options:
#            a: 1
#            b: true
#
# ```

# %% [markdown]
# Why making splitting the request in path and provider?
#
# Because in actual projects, you don't want to hardcode the resource.
# Think for instance at user-specific locations, or at dev/test/stage/prod profiles for data processing.
# This API is meant to be flexible enough to support these scenario's, yet easy enough for prototyping and experimentation.

# %%
from datafaucet.resource import *

# %%
metadata.load()
tests = [
    resource('SELECT 0 as result where 1 = 0', 'pagila'),
    resource('foo.csv', '/bar'),
    resource('foo.csv', 'bar'),
    resource('foo.csv', 'hdfs'),
    resource('/foo.abc', 'hdfs'),
    resource('/foo.abc', 'test'),
    resource('hello/foo.abc', 'test'),
    resource('foo.abc', 'hdfs://hdfs-namenode:8020/wanna/dance/with/somebody'),
    resource('/foo.abc', 'hdfs://hdfs-namenode/wanna/dance/with/somebody'),
    resource('/foo.abc', 'hdfs://hdfs-namenode:8020/wanna/dance/with/somebody'),
    resource('staff', 'jdbc:mysql://1.2.3.4:3306/sakila?useSSL=false&serverTimezone=UTC&zeroDateTimeBehavior=CONVERT_TO_NULL'),
    resource('staff', 'jdbc:mysql://pippo:baudo@1.2.3.4:3306/sakila?useSSL=false&serverTimezone=UTC&zeroDateTimeBehavior=CONVERT_TO_NULL'),
    resource('staff', 'jdbc:mysql://pippo:baudo@1.2.3.4:3306/sakila?useSSL=false&serverTimezone=UTC&zeroDateTimeBehavior=CONVERT_TO_NULL', useSSL='new!', serverTimezone='new!'),
    resource('staff', 'jdbc:mysql://1.2.3.4/sakila', useSSL='false', serverTimezone='UTC', zeroDateTimeBehavior='CONVERT_TO_NULL'),
    resource('staff', service='mysql', database='sakila', serverTimezone='UTC'),
    resource('sakila/staff', service='mysql', serverTimezone='UTC', user='pippo', password='baudo'),
    resource('foo/bar.tsv', service='s3a'),
    resource('/foo/bar.tsv', service='s3a'),
    resource('/apples/orange', service='minio'),
    resource('SELECT count(*) as cnt from employees;', 'jdbc:mysql://1.2.3.4:3306/sakila?useSSL=false&serverTimezone=UTC&zeroDateTimeBehavior=CONVERT_TO_NULL', user='pippo', password='baudo'),
    resource('ascombe'),
    resource('ascombe', 'saywhat'),
    resource('ascombe', 'hdfs://hdfs-namenode:8020/otherpath/'),
    resource('ascombe', 'hdfs'),
    resource('ascombe', 'test'),
    resource('r_test', 'test'),
]

s = """
    resource('SELECT 0 as result where 1 = 0', 'pagila'),
    resource('foo.csv', '/bar'),
    resource('foo.csv', 'bar'),
    resource('foo.csv', 'hdfs'),
    resource('/foo.abc', 'hdfs'),
    resource('/foo.abc', 'test'),
    resource('hello/foo.abc', 'test'),
    resource('foo.abc', 'hdfs://hdfs-namenode:8020/wanna/dance/with/somebody'),
    resource('/foo.abc', 'hdfs://hdfs-namenode/wanna/dance/with/somebody'),
    resource('/foo.abc', 'hdfs://hdfs-namenode:8020/wanna/dance/with/somebody'),
    resource('staff', 'jdbc:mysql://1.2.3.4:3306/sakila?useSSL=false&serverTimezone=UTC&zeroDateTimeBehavior=CONVERT_TO_NULL'),
    resource('staff', 'jdbc:mysql://pippo:baudo@1.2.3.4:3306/sakila?useSSL=false&serverTimezone=UTC&zeroDateTimeBehavior=CONVERT_TO_NULL'),
    resource('staff', 'jdbc:mysql://pippo:baudo@1.2.3.4:3306/sakila?useSSL=false&serverTimezone=UTC&zeroDateTimeBehavior=CONVERT_TO_NULL', useSSL='new!', serverTimezone='new!'),
    resource('staff', 'jdbc:mysql://1.2.3.4/sakila', useSSL='false', serverTimezone='UTC', zeroDateTimeBehavior='CONVERT_TO_NULL'),
    resource('staff', service='mysql', database='sakila', serverTimezone='UTC'),
    resource('sakila/staff', service='mysql', serverTimezone='UTC', user='pippo', password='baudo'),
    resource('foo/bar.tsv', service='s3a'),
    resource('/foo/bar.tsv', service='s3a'),
    resource('/apples/orange', service='minio'),
    resource('SELECT count(*) as cnt from employees;', 'jdbc:mysql://1.2.3.4:3306/sakila?useSSL=false&serverTimezone=UTC&zeroDateTimeBehavior=CONVERT_TO_NULL', user='pippo', password='baudo'),
    resource('ascombe'),
    resource('ascombe', 'saywhat'),
    resource('ascombe', 'hdfs://hdfs-namenode:8020/otherpath/'),
    resource('ascombe', 'hdfs'),
    resource('ascombe', 'test'),
    resource('r_test', 'test'),
""".split('),')

for t in zip(s, tests):
    print('#'*10)
    print(t[0].lstrip()+')')
    print('-'*10)
    print(t[1])
# Out:
# ##########
# resource('SELECT 0 as result where 1 = 0', 'pagila')
# ----------
# hash: '0x91507a3213f163a3'
# url: jdbc:postgresql://127.0.0.1:5432/pagila
# service: postgres
# format: jdbc
# host: 127.0.0.1
# port: 5432
# driver: org.postgresql.Driver
# database: pagila
# schema: public
# table: ( SELECT 0 as result where 1 = 0 ) as _query
# user:
# password: postgres
# options: {}
#
# ##########
# resource('foo.csv', '/bar')
# ----------
# hash: '0x3970b796b788cffb'
# url: /bar/foo.csv
# service: file
# format: csv
# host: 127.0.0.1
# options: {}
#
# ##########
# resource('foo.csv', 'bar')
# ----------
# hash: '0xb92c7417c6d17d69'
# url: /home/jovyan/work/tutorial/bar/foo.csv
# service: file
# format: csv
# host: 127.0.0.1
# options: {}
#
# ##########
# resource('foo.csv', 'hdfs')
# ----------
# hash: '0xf74c5a930e36238'
# url: hdfs://127.0.0.1:8020/foo.csv
# service: hdfs
# format: csv
# host: 127.0.0.1
# port: 8020
# options:
#     header: true
#     inferSchema: true
#
# ##########
# resource('/foo.abc', 'hdfs')
# ----------
# hash: '0x7268d550e983ee5'
# url: hdfs://127.0.0.1:8020/foo.abc
# service: hdfs
# format: abc
# host: 127.0.0.1
# port: 8020
# options:
#     header: true
#     inferSchema: true
#
# ##########
# resource('/foo.abc', 'test')
# ----------
# hash: '0xe514252a9ccfa73e'
# url: hdfs://hdfs-namenode:8020/foo.abc
# service: hdfs
# format: abc
# host: hdfs-namenode
# port: '8020'
# options:
#     overwrite_option: a
#     b: true
#
# ##########
# resource('hello/foo.abc', 'test')
# ----------
# hash: '0x49696871d0fc8727'
# url: hdfs://hdfs-namenode:8020/wanna/dance/with/somebody/hello/foo.abc
# service: hdfs
# format: abc
# host: hdfs-namenode
# port: '8020'
# options:
#     overwrite_option: a
#     b: true
#
# ##########
# resource('foo.abc', 'hdfs://hdfs-namenode:8020/wanna/dance/with/somebody')
# ----------
# hash: '0xefc5e7e92249567a'
# url: hdfs://hdfs-namenode:8020/wanna/dance/with/somebody/foo.abc
# service: hdfs
# format: abc
# host: hdfs-namenode
# port: '8020'
# options: {}
#
# ##########
# resource('/foo.abc', 'hdfs://hdfs-namenode/wanna/dance/with/somebody')
# ----------
# hash: '0xe514252a9ccfa73e'
# url: hdfs://hdfs-namenode:8020/foo.abc
# service: hdfs
# format: abc
# host: hdfs-namenode
# port: 8020
# options: {}
#
# ##########
# resource('/foo.abc', 'hdfs://hdfs-namenode:8020/wanna/dance/with/somebody')
# ----------
# hash: '0xe514252a9ccfa73e'
# url: hdfs://hdfs-namenode:8020/foo.abc
# service: hdfs
# format: abc
# host: hdfs-namenode
# port: '8020'
# options: {}
#
# ##########
# resource('staff', 'jdbc:mysql://1.2.3.4:3306/sakila?useSSL=false&serverTimezone=UTC&zeroDateTimeBehavior=CONVERT_TO_NULL')
# ----------
# hash: '0x32ab695c754e8055'
# url: jdbc:mysql://1.2.3.4:3306/sakila
# service: mysql
# format: jdbc
# host: 1.2.3.4
# port: '3306'
# driver: com.mysql.cj.jdbc.Driver
# database: sakila
# schema: sakila
# table: staff
# user:
# password:
# options:
#     useSSL: 'false'
#     serverTimezone: UTC
#     zeroDateTimeBehavior: CONVERT_TO_NULL
#
# ##########
# resource('staff', 'jdbc:mysql://pippo:baudo@1.2.3.4:3306/sakila?useSSL=false&serverTimezone=UTC&zeroDateTimeBehavior=CONVERT_TO_NULL')
# ----------
# hash: '0x32ab695c754e8055'
# url: jdbc:mysql://1.2.3.4:3306/sakila
# service: mysql
# format: jdbc
# host: 1.2.3.4
# port: '3306'
# driver: com.mysql.cj.jdbc.Driver
# database: sakila
# schema: sakila
# table: staff
# user: pippo
# password: baudo
# options:
#     useSSL: 'false'
#     serverTimezone: UTC
#     zeroDateTimeBehavior: CONVERT_TO_NULL
#
# ##########
# resource('staff', 'jdbc:mysql://pippo:baudo@1.2.3.4:3306/sakila?useSSL=false&serverTimezone=UTC&zeroDateTimeBehavior=CONVERT_TO_NULL', useSSL='new!', serverTimezone='new!')
# ----------
# hash: '0x32ab695c754e8055'
# url: jdbc:mysql://1.2.3.4:3306/sakila
# service: mysql
# format: jdbc
# host: 1.2.3.4
# port: '3306'
# driver: com.mysql.cj.jdbc.Driver
# database: sakila
# schema: sakila
# table: staff
# user: pippo
# password: baudo
# options:
#     zeroDateTimeBehavior: CONVERT_TO_NULL
#     useSSL: new!
#     serverTimezone: new!
#
# ##########
# resource('staff', 'jdbc:mysql://1.2.3.4/sakila', useSSL='false', serverTimezone='UTC', zeroDateTimeBehavior='CONVERT_TO_NULL')
# ----------
# hash: '0x32ab695c754e8055'
# url: jdbc:mysql://1.2.3.4:3306/sakila
# service: mysql
# format: jdbc
# host: 1.2.3.4
# port: 3306
# driver: com.mysql.cj.jdbc.Driver
# database: sakila
# schema: sakila
# table: staff
# user:
# password:
# options:
#     useSSL: 'false'
#     serverTimezone: UTC
#     zeroDateTimeBehavior: CONVERT_TO_NULL
#
# ##########
# resource('staff', service='mysql', database='sakila', serverTimezone='UTC')
# ----------
# hash: '0xf9571d18adc2f454'
# url: jdbc:mysql://127.0.0.1:3306/sakila
# service: mysql
# format: jdbc
# host: 127.0.0.1
# port: 3306
# driver: com.mysql.cj.jdbc.Driver
# database: sakila
# schema: sakila
# table: sakila
# user:
# password:
# options:
#     serverTimezone: UTC
#
# ##########
# resource('sakila/staff', service='mysql', serverTimezone='UTC', user='pippo', password='baudo')
# ----------
# hash: '0x126a7c72bc1fa36a'
# url: jdbc:mysql://127.0.0.1:3306/sakila
# service: mysql
# format: jdbc
# host: 127.0.0.1
# port: 3306
# driver: com.mysql.cj.jdbc.Driver
# database: sakila
# schema: sakila
# table: staff
# user: pippo
# password: baudo
# options:
#     serverTimezone: UTC
#
# ##########
# resource('foo/bar.tsv', service='s3a')
# ----------
# hash: '0xd745eecc62488874'
# url: s3a://foo/bar.tsv'
# service: s3a
# format: tsv
# host: 127.0.0.1
# port: 9000
# options: {}
#
# ##########
# resource('/foo/bar.tsv', service='s3a')
# ----------
# hash: '0xd745eecc62488874'
# url: s3a://foo/bar.tsv'
# service: s3a
# format: tsv
# host: 127.0.0.1
# port: 9000
# options: {}
#
# ##########
# resource('/apples/orange', service='minio')
# ----------
# hash: '0xe6cf5c272f2b8ee4'
# url: s3a://apples/orange'
# service: s3a
# format:
# host: 127.0.0.1
# port: 9000
# options: {}
#
# ##########
# resource('SELECT count(*) as cnt from employees;', 'jdbc:mysql://1.2.3.4:3306/sakila?useSSL=false&serverTimezone=UTC&zeroDateTimeBehavior=CONVERT_TO_NULL', user='pippo', password='baudo')
# ----------
# hash: '0xbab228919b379996'
# url: jdbc:mysql://1.2.3.4:3306/sakila
# service: mysql
# format: jdbc
# host: 1.2.3.4
# port: '3306'
# driver: com.mysql.cj.jdbc.Driver
# database: sakila
# schema: sakila
# table: ( SELECT count(*) as cnt from employees ) as _query
# user: pippo
# password: baudo
# options:
#     useSSL: 'false'
#     serverTimezone: UTC
#     zeroDateTimeBehavior: CONVERT_TO_NULL
#
# ##########
# resource('ascombe')
# ----------
# hash: '0xe72dc26b3dae81e1'
# url: /home/jovyan/work/tutorial/data/ascombe.csv
# service: file
# format: csv
# host: 127.0.0.1
# options:
#     header: true
#     inferSchema: true
#
# ##########
# resource('ascombe', 'saywhat')
# ----------
# hash: '0xcf666cb1421f840a'
# url: /home/jovyan/work/tutorial/saywhat/ascombe.csv
# service: file
# format: csv
# host: 127.0.0.1
# options: {}
#
# ##########
# resource('ascombe', 'hdfs://hdfs-namenode:8020/otherpath/')
# ----------
# hash: '0xea36737e63fd1cbf'
# url: hdfs://hdfs-namenode:8020/otherpath/ascombe.csv
# service: hdfs
# format: csv
# host: hdfs-namenode
# port: '8020'
# options: {}
#
# ##########
# resource('ascombe', 'hdfs')
# ----------
# hash: '0x128b78de03f52298'
# url: hdfs://127.0.0.1:8020/ascombe.csv
# service: hdfs
# format: csv
# host: 127.0.0.1
# port: 8020
# options:
#     header: true
#     inferSchema: true
#
# ##########
# resource('ascombe', 'test')
# ----------
# hash: '0x86caa2ff764159a4'
# url: hdfs://hdfs-namenode:8020/wanna/dance/with/somebody/ascombe.csv
# service: hdfs
# format: csv
# host: hdfs-namenode
# port: '8020'
# options:
#     overwrite_option: a
#     b: true
#
# ##########
# resource('r_test', 'test')
# ----------
# hash: '0xee6b459c8977f2f0'
# url: hdfs://hdfs-namenode:8020/wanna/dance/with/somebody/abc.avro
# service: hdfs
# format: avro
# host: hdfs-namenode
# port: '8020'
# options:
#     overwrite_option: overwritten
#     b: true
#     a: true

# %%
resource('staff.csv', 'abracadabra')
# Out:
# hash: '0x32e53bf0099609fb'
# url: /home/jovyan/work/tutorial/abracadabra/staff.csv
# service: file
# format: csv
# host: 127.0.0.1
# port:
# options: {}

# %%
resource('file:///home/jovyan/work/tutorial/abracadabra/staff.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-1ec399adebf3> in <module>()
# ----> 1 resource('file:///home/jovyan/work/tutorial/abracadabra/staff.csv')
#
# ~/develop/datafaucet/datafaucet/resource.py in resource(path_or_alias_or_url, provider_path_or_alias_or_url, host, service, port, user, password, driver, database, schema, table, format, hostname, username, **options)
#     383
#     384     # get the provider, by alias metadata or by url
# --> 385     pmd = to_resource(prov)
#     386
#     387     # merge provider and resource metadata
#
# ~/develop/datafaucet/datafaucet/resource.py in to_resource(url_alias, *args, **kwargs)
#     192     # if nothing found yet, interpret as a urn/path
#     193     if not md:
# --> 194         md = resource_from_urn(urnparse(url_alias))
#     195
#     196     # sanitize path if it's a url
#
# ~/develop/datafaucet/datafaucet/resource.py in urnparse(s)
#      28
#      29 def urnparse(s):
# ---> 30     scheme, url = tsplit(s, '//')
#      31
#      32     path_only = ((not scheme) or
#
# ~/develop/datafaucet/datafaucet/resource.py in tsplit(s, sep, shift)
#      21
#      22 def tsplit(s, sep, shift='left'):
# ---> 23     s = s.split(sep)
#      24     if shift=='left':
#      25         return (s[0],s[1]) if len(s)>1 else ('', s[0])
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
import functools
functools.reduce(lambda a,b: a^b, [10,10,10, 10])
# Out:
# 0

# %%
from datafaucet.resource import resource

# %%
jdbc = resource('jdbc:mysql://1.2.3.4/sakila', useSSL='false', serverTimezone='UTC', zeroDateTimeBehavior='CONVERT_TO_NULL')
jdbc
# Out:
# hash: '0x91bc765d6b9d670f'
# url: jdbc:mysql://1.2.3.4:3306/sakila
# service: mysql
# format: jdbc
# host: 1.2.3.4
# port: 3306
# driver: com.mysql.cj.jdbc.Driver
# database: sakila
# schema: sakila
# table: ( SELECT 0 as result where 1 = 0 ) as _query
# user:
# password:
# options:
#     useSSL: 'false'
#     serverTimezone: UTC
#     zeroDateTimeBehavior: CONVERT_TO_NULL

# %%
table = resource('staff')
table
# Out:
# hash: '0xe483b933cd090226'
# url: /home/jovyan/work/tutorial/staff
# service: file
# format:
# host: 127.0.0.1
# port:
# options: {}

# %%
resource('foobar', table)
# Out:
# hash: '0xedff646c33db78c0'
# url: /home/jovyan/work/tutorial/staff/foobar
# service: file
# format:
# host: 127.0.0.1
# port:
# options: {}
